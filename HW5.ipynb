# max      10.535100    10.535100    10.535100    10.535100    10.535100
#
#            SVENF27      SVENF28      SVENF29      SVENF30    Adj_Close
# count  8071.000000  8071.000000  8071.000000  8071.000000  8071.000000
# mean      5.355063     5.290948     5.228333     5.167371     5.509793
# std       1.810643     1.820541     1.832984     1.847834     2.491110
# min       0.681200     0.577100     0.487600     0.411100     2.801050
# 25%       3.887150     3.840900     3.825050     3.831350     3.130587
# 50%       4.979700     4.860800     4.758600     4.669000     4.956219
# 75%       6.765400     6.650600     6.535450     6.421850     8.051437
# max      10.535100    10.535100    10.535100    10.535100    10.150118
#
# [8 rows x 31 columns]

# %% [markdown]
# randomly sampled yield curves and plot them

# %%
size=20
plt.figure(figsize=(15,15))
df.sample(size).T[1:-1].plot()
plt.ylabel('yield rate')
plt.xlabel('maturity period')
plt.show()

# %% [markdown]
# we randomly pick 10 maturities and check for correlations and notice that the data is highly correlated

# %%
sn.pairplot(df.T.sample(10).T)
plt.show()

# %% [markdown]
# data standardisation

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
y=df['Adj_Close']

# %%
X=df.drop(columns=['Adj_Close','Date'])

# %%
X
# Out:
#       SVENF01  SVENF02  SVENF03  SVENF04  SVENF05  SVENF06  SVENF07  SVENF08  \
# 0      2.1224   2.0266   2.1023   2.2377   2.3790   2.5042   2.6069   2.6885
# 1      2.1239   2.0317   2.1096   2.2468   2.3901   2.5171   2.6217   2.7049
# 2      2.0874   1.9956   2.0844   2.2289   2.3736   2.4980   2.5984   2.6779
# 3      2.1319   2.0559   2.1451   2.2856   2.4257   2.5461   2.6428   2.7188
# 4      2.1051   2.0234   2.1180   2.2632   2.4051   2.5248   2.6198   2.6940
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 8066   6.1632   6.6192   6.9560   7.2403   7.4888   7.7032   7.8831   8.0295
# 8067   6.2091   6.6589   6.9843   7.2634   7.5140   7.7355   7.9250   8.0814
# 8068   6.2195   6.6790   7.0240   7.3172   7.5738   7.7951   7.9805   8.1314
# 8069   6.2215   6.6978   7.0637   7.3688   7.6270   7.8421   8.0168   8.1551
# 8070   6.2102   6.6709   7.0310   7.3333   7.5890   7.8010   7.9722   8.1067
#
#       SVENF09  SVENF10  ...  SVENF21  SVENF22  SVENF23  SVENF24  SVENF25  \
# 0      2.7530   2.8054  ...   3.2840   3.3355   3.3876   3.4400   3.4925
# 1      2.7710   2.8247  ...   3.3063   3.3574   3.4091   3.4610   3.5130
# 2      2.7418   2.7951  ...   3.3089   3.3589   3.4086   3.4575   3.5055
# 3      2.7791   2.8289  ...   3.3396   3.3940   3.4485   3.5029   3.5568
# 4      2.7532   2.8029  ...   3.3192   3.3712   3.4227   3.4735   3.5234
# ...       ...      ...  ...      ...      ...      ...      ...      ...
# 8066   8.1454   8.2350  ...   8.4763   8.4777   8.4787   8.4794   8.4799
# 8067   8.2067   8.3044  ...   8.5720   8.5737   8.5748   8.5756   8.5761
# 8068   8.2507   8.3430  ...   8.5920   8.5936   8.5946   8.5953   8.5958
# 8069   8.2619   8.3428  ...   8.5492   8.5503   8.5511   8.5516   8.5519
# 8070   8.2099   8.2875  ...   8.4812   8.4822   8.4829   8.4834   8.4836
#
#       SVENF26  SVENF27  SVENF28  SVENF29  SVENF30
# 0      3.5446   3.5962   3.6471   3.6970   3.7458
# 1      3.5646   3.6156   3.6660   3.7153   3.7636
# 2      3.5524   3.5980   3.6421   3.6847   3.7257
# 3      3.6099   3.6622   3.7132   3.7630   3.8113
# 4      3.5722   3.6196   3.6655   3.7098   3.7525
# ...       ...      ...      ...      ...      ...
# 8066   8.4802   8.4804   8.4805   8.4806   8.4807
# 8067   8.5764   8.5767   8.5768   8.5769   8.5770
# 8068   8.5961   8.5963   8.5965   8.5966   8.5966
# 8069   8.5522   8.5523   8.5524   8.5525   8.5525
# 8070   8.4838   8.4840   8.4841   8.4841   8.4841
#
# [8071 rows x 30 columns]

# %%
y
# Out:
# 0       10.130177
# 1       10.130177
# 2       10.150118
# 3       10.130177
# 4       10.130177
#           ...
# 8066     2.942279
# 8067     2.942279
# 8068     2.942279
# 8069     2.942279
# 8070     2.942279
# Name: Adj_Close, Length: 8071, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size = 0.20,random_state=42)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# # 5 fold CV function and normal regression

# %%
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# Basic test

# %%
def predict_model(regression_model,X,y):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size = 0.20,random_state=42)
    
    scaler=StandardScaler()
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    
    model = regression_model
    model.fit(X_train,y_train)
    
    r2_train = r2_score(y_train, model.predict(X_train))
    r2_test = r2_score(y_test, model.predict(X_test))
    
    print(f" Coefficient of Determination for test:- {np.round(r2_test,4)} , train:- {np.round(r2_train,4)}")
    return model

# %%
def five_fold_CV(regression_model,X,y):
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    train_R2=[]
    test_R2=[]
    for train_index, test_index in kf.split(X):
        # Split data into training and test sets
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        scaler=StandardScaler()
        X_train=scaler.fit_transform(X_train)
        X_test=scaler.transform(X_test)
        
        # Fit model on training data
        model = regression_model
        model.fit(X_train, y_train)
        
        # Compute training and test mean squared error
        train_R2.append(r2_score(y_train, model.predict(X_train)))
        test_R2.append(r2_score(y_test, model.predict(X_test)))
    
    print(f"Average Coefficient of Determination using 5-fold crossvalidation test:- {np.round(np.mean(test_R2),4)} , train:- {np.round(np.mean(train_R2),4)} ")

# %% [markdown]
# # SGD Linear Regression

# %%
from sklearn.linear_model import SGDRegressor

# %% [markdown]
# ## no penalty

# %%
clf_sgd = SGDRegressor(loss='squared_error',penalty=None, random_state=42)

# %%
clf_sgd_model=predict_model(clf_sgd,X,y)
# Out:
#  Coefficient of Determination for test:- 0.885 , train:- 0.8895

# %%
five_fold_CV(clf_sgd,X,y)
# Out:
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.8902 , train:- 0.8905

# %%
clf_sgd_model.coef_
# Out:
# array([-0.42177671, -0.42259219, -0.25351262, -0.05098327,  0.09065082,
#         0.15461054,  0.15705357,  0.12072588,  0.06474147,  0.00207166,
#        -0.05952395, -0.11580586, -0.16473506, -0.20544162, -0.23755992,
#        -0.26084984, -0.27512626, -0.28002293, -0.27525021, -0.26037731,
#        -0.23514386, -0.19935585, -0.15295337, -0.09613126, -0.02925101,
#         0.04714467,  0.13224908,  0.22518231,  0.3248683 ,  0.43031743])

# %% [markdown]
# ## L1 penalty

# %%
clf_sgd_l1 = SGDRegressor(loss='squared_error',penalty='l1', random_state=42)

# %%
clf_sgd_l1_model=predict_model(clf_sgd_l1,X,y)
# Out:
#  Coefficient of Determination for test:- 0.8851 , train:- 0.8896

# %%
five_fold_CV(clf_sgd_l1,X,y)
# Out:
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.8902 , train:- 0.8905

# %%
clf_sgd_l1_model.coef_
# Out:
# array([-0.42338602, -0.42232028, -0.25036413, -0.04517691,  0.0874581 ,
#         0.15222341,  0.15460842,  0.11758881,  0.06051158,  0.        ,
#        -0.05559368, -0.11315521, -0.16321984, -0.20486482, -0.23769242,
#        -0.26144606, -0.275936  , -0.2808001 , -0.2757595 , -0.2603991 ,
#        -0.23447799, -0.19782412, -0.15040152, -0.09242986, -0.02429575,
#         0.0426331 ,  0.12912664,  0.22348273,  0.32460518,  0.43148669])

# %% [markdown]
# ## L2 penalty

# %%
clf_sgd_l2 = SGDRegressor(loss='squared_error',penalty='l2', random_state=42)

# %%
clf_sgd_l2_model=predict_model(clf_sgd_l2,X,y)
# Out:
#  Coefficient of Determination for test:- 0.885 , train:- 0.8895

# %%
five_fold_CV(clf_sgd_l2,X,y)
# Out:
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.8902 , train:- 0.8905

# %%
clf_sgd_l2_model.coef_
# Out:
# array([-0.42185779, -0.42233674, -0.25331861, -0.0509916 ,  0.09049306,
#         0.15439251,  0.1568401 ,  0.12054911,  0.06460972,  0.00198112,
#        -0.05958074, -0.11583537, -0.16474089, -0.20542439, -0.23751819,
#        -0.26078141, -0.27502937, -0.27989751, -0.2750984 , -0.26020424,
#        -0.23495753, -0.19916718, -0.15277599, -0.09598088, -0.02914495,
#         0.04718804,  0.13221115,  0.22504467,  0.32461341,  0.42992866])

# %% [markdown]
# No significant increase in R squared with the penalised models

# %% [markdown]
# # SVM regression

# %%
from sklearn import svm

# %% [markdown]
# ## Linear SVR

# %%
svr = svm.SVR(kernel="linear")

# %%
svr_model=predict_model(svr,X,y)
# Out:
#  Coefficient of Determination for test:- 0.8888 , train:- 0.8927

# %%
five_fold_CV(svr,X,y)
# Out:
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.8915 , train:- 0.892

# %%
svr_model.coef_
# Out:
# array([[ 1.17971523, -2.66984888, -2.46932956,  0.97081816,  2.65403412,
#          2.18427585,  0.67102701, -0.86088167, -1.84449214, -2.13031462,
#         -1.81785556, -1.11175564, -0.24349009,  0.58257657,  1.21701781,
#          1.57706146,  1.62380288,  1.3847242 ,  0.90146074,  0.26393027,
#         -0.44000476, -1.11100538, -1.65071035, -1.97366875, -2.00432314,
#         -1.68253267, -0.97245077,  0.15197393,  1.6899938 ,  3.64189647]])

# %% [markdown]
# ## Polynomial SVR

# %%
svr_p = svm.SVR(kernel="poly")

# %%
svr_p_model=predict_model(svr_p,X,y)
# Out:
#  Coefficient of Determination for test:- 0.7748 , train:- 0.7908

# %%
five_fold_CV(svr_p,X,y)
# Out:
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.7858 , train:- 0.7871

# %% [markdown]
# ## RBF SVR

# %%
svr_rbf = svm.SVR(kernel="rbf")

# %%
svr_rbf_model=predict_model(svr_rbf,X,y)
# Out:
#  Coefficient of Determination for test:- 0.9891 , train:- 0.9885

# %%
five_fold_CV(svr_rbf,X,y)
# Out:
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.9884 , train:- 0.9886

# %% [markdown]
# we see the polynomial function doesn't improve on the linear svr and does far worse but the rbf svr outperforms all the models we tested till now.

# %% [markdown]
# # Transform the data with PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=X.shape[1])
pca.fit(X)

# Plot explained variance ratio
plt.bar(range(0, pca.n_components_), pca.explained_variance_ratio_)
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance vs principal components')
plt.show()

# %% [markdown]
# looks like most of the variance is explained by the first term while a little bit is explained by the second and third

# %%
# lets check optimal number of components with mle
pca_mle = PCA(n_components='mle')
pca_mle.fit(X)
print(f"based on mle method we get {pca_mle.n_components_} components ")
# Out:
# based on mle method we get 13 components

# %% [markdown]
# ## Taking just 1 component we get

# %%
pca1 = PCA(n_components=1)
X_pca1 = pd.DataFrame(pca1.fit_transform(X))

# %%
np.shape(X_pca1)
# Out:
# (8071, 1)

# %% [markdown]
# ## Linear Regression

# %%
clf_sgd = SGDRegressor(loss='squared_error',penalty=None, random_state=42)
clf_sgd_model = predict_model(clf_sgd,X_pca1,y)
five_fold_CV(clf_sgd,X_pca1,y)
clf_sgd_model.coef_
# Out:
#  Coefficient of Determination for test:- 0.8233 , train:- 0.8251
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.8243 , train:- 0.8247
# array([-2.28470199])

# %% [markdown]
# ## Linear SVR

# %%
svr = svm.SVR(kernel="linear")
svr_model=predict_model(svr,X_pca1,y)
five_fold_CV(svr,X_pca1,y)
svr_model.coef_
# Out:
#  Coefficient of Determination for test:- 0.8229 , train:- 0.8248
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.8238 , train:- 0.8244
# array([[-2.31951166]])

# %% [markdown]
# ## Polynomial SVR

# %%
svr_p = svm.SVR(kernel="poly")
svr_p_model=predict_model(svr_p,X_pca1,y)
five_fold_CV(svr_p,X_pca1,y)
# Out:
#  Coefficient of Determination for test:- 0.4971 , train:- 0.4802
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.4787 , train:- 0.4801

# %% [markdown]
# ## RBF SVR

# %%
svr_rbf = svm.SVR(kernel="rbf")
svr_rbf_model=predict_model(svr_rbf,X_pca1,y)
five_fold_CV(svr_rbf,X_pca1,y)
# Out:
#  Coefficient of Determination for test:- 0.9295 , train:- 0.9271
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.9274 , train:- 0.9276

# %% [markdown]
# # Taking 3 components we get

# %%
pca3 = PCA(n_components=3)
X_pca3 = pd.DataFrame(pca3.fit_transform(X))
np.shape(X_pca3)
# Out:
# (8071, 3)

# %% [markdown]
# ## Linear Regression

# %%
clf_sgd = SGDRegressor(loss='squared_error',penalty=None, random_state=42)
clf_sgd_model = predict_model(clf_sgd,X_pca3,y)
five_fold_CV(clf_sgd,X_pca3,y)
clf_sgd_model.coef_
# Out:
#  Coefficient of Determination for test:- 0.8618 , train:- 0.8683
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.8669 , train:- 0.8672
# array([-2.27781805, -0.50429221,  0.02562629])

# %% [markdown]
# ## Linear SVR

# %%
svr = svm.SVR(kernel="linear")
svr_model=predict_model(svr,X_pca3,y)
five_fold_CV(svr,X_pca3,y)
svr_model.coef_
# Out:
#  Coefficient of Determination for test:- 0.8561 , train:- 0.8638
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.8619 , train:- 0.8622
# array([[-2.3871901 , -0.62394811,  0.06319533]])

# %% [markdown]
# ## Polynomial SVR

# %%
svr_p = svm.SVR(kernel="poly")
svr_p_model=predict_model(svr_p,X_pca3,y)
five_fold_CV(svr_p,X_pca3,y)
# Out:
#  Coefficient of Determination for test:- 0.7028 , train:- 0.7213
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.7143 , train:- 0.7166

# %% [markdown]
# ## RBF SVR

# %%
svr_rbf = svm.SVR(kernel="rbf")
svr_rbf_model=predict_model(svr_rbf,X_pca3,y)
five_fold_CV(svr_rbf,X_pca3,y)
# Out:
#  Coefficient of Determination for test:- 0.9824 , train:- 0.982
# Average Coefficient of Determination using 5-fold crossvalidation test:- 0.982 , train:- 0.9821

# %%
result=pd.DataFrame({"index":["baseline train","baseline test","PCA 3 train","PCA 3 test"],"linear":[0.8895,0.885,0.8683,0.8618],"SVR":[0.8927,0.8888,0.8638,0.8561]})
result=result.set_index("index")
result.index.names = [None]

# %%
result
# Out:
#                 linear     SVR
# baseline train  0.8895  0.8927
# baseline test   0.8850  0.8888
# PCA 3 train     0.8683  0.8638
# PCA 3 test      0.8618  0.8561

# %% [markdown]
# ## above results are for linear regression without penalty and for SVR with linear kernel other models perform better

# %%
print("My name is Samanvay Malapally Sudhakara")
print("My NetID is: SM105")
print("I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.")
# Out:
# My name is Samanvay Malapally Sudhakara
# My NetID is: SM105
# I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.
